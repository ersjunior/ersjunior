# %% [markdown]
# <a href="https://colab.research.google.com/github/ersjunior/ersjunior/blob/main/Data_Risk_Analytics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src='https://seeklogo.com/images/S/stone-pagamentos-logo-781DFFF629-seeklogo.com.png' width="100" height="40"/>

# %% [markdown]
# Este notebook foi criado para responder às perguntas do [Desafio de Data Risk Analytics](https://github.com/KormannLau/desafio-de-data-risk-analytics/blob/feat/add-doc-desafio/case_risk_analytics.md).

# %%
# Instalando a API do Google
# !pip install gspread
# !pip install gspread-dataframe
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# Import bibliotecas
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import gspread
from gspread_dataframe import get_as_dataframe, set_with_dataframe
from google.colab import auth
auth.authenticate_user()  # Verificação da conta para leituras dos dados
from google.auth import default
creds, _ = default()
gc = gspread.authorize(creds)

# %%
# Criando DF para base recebida

base_stone = gc.open("Base_Stone").sheet1  # Para abrir a planilha do drive
dados = base_stone.get_all_values()  # Pegando os dados da planilha
df_base = pd.DataFrame(dados)
df_base
# Out:
#                       0     1              2                           3   \
# 0      Número do Cliente   MCC  Data Apuração  Data de Entrada do Cliente
# 1        100910138884288  5309      10/1/2016                    1/7/2016
# 2        100101693498007  5963      10/1/2016                  12/10/2015
# 3        100990966870135  5814      10/1/2016                   3/29/2016
# 4        100112746462403  7230      10/1/2016                   7/26/2016
# ...                  ...   ...            ...                         ...
# 12452    100844518929288  5661       2/1/2017                    1/4/2017
# 12453    100858063287119  5812       2/1/2017                    1/4/2017
# 12454    100937318440605  5812       2/1/2017                   11/3/2016
# 12455    100854761191043  5732       2/1/2017                    1/4/2017
# 12456    100828905749205  5211       2/1/2017                   11/4/2016
#
#             4               5                      6   \
# ...
